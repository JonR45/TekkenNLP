# %%
import os
os.chdir('..') # this resolves ImportError: attempted relative import with no known parent package
from dotenv import load_dotenv
load_dotenv()

import googleapiclient.discovery
import pandas as pd
from src.api.get_youtube_data import get_video_ids, get_video_data
from tqdm.notebook import tqdm
import time

# %%
# set parameters for creating a youtube service object
api_service_name = "youtube"
api_version = "v3"
API_KEY = os.environ.get("API_KEY")

# create a youtube service object
youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=API_KEY)

# %%
# set channel and search details
bandai_namco_america_id = "UC_ntXHv-XdKCD7CPynVvnQw"
published_after = "2023-11-01T00:00:00Z"
published_before = "2023-12-21T00:00:00Z"
search_term = "tekken"

# %% [markdown]
# - The `get_video_comments` function will take in video IDs as input so we need to gather some video ids with `get_video_ids`
# - Use `get_video_data` to create a dataframe with only the video IDs and data for videos that contain "Tekken" in the title, as we want to extract comments about the upcoming release of Tekken 8.

# %%
# get video Ids
video_ids = get_video_ids(youtube_service_object=youtube, 
                          channel_id=bandai_namco_america_id,
                         published_before=published_before,
                         published_after=published_after,
                         search_term=search_term)

# %%
len(video_ids)
# Out:
# 26

# %%
df = get_video_data(youtube_service_object=youtube, video_ids=video_ids)
df.head()
# Out:
# 0it [00:00, ?it/s]
# Batch 1 start: 0
# Batch 1 end: 26
#                          channelTitle                 channelId      videoId  \
# 0  Bandai Namco Entertainment America  UC_ntXHv-XdKCD7CPynVvnQw  rDxrpSqYHD8
# 1  Bandai Namco Entertainment America  UC_ntXHv-XdKCD7CPynVvnQw  cIDK50IaVpg
# 2  Bandai Namco Entertainment America  UC_ntXHv-XdKCD7CPynVvnQw  PsCpewoF2E4
# 3  Bandai Namco Entertainment America  UC_ntXHv-XdKCD7CPynVvnQw  QH6s_o3dIic
# 4  Bandai Namco Entertainment America  UC_ntXHv-XdKCD7CPynVvnQw  Zc-yMi05vBA
#
#                 publishedAt  \
# 0 2023-11-01 16:09:18+00:00
# 1 2023-11-02 13:22:49+00:00
# 2 2023-11-13 05:03:26+00:00
# 3 2023-11-22 14:00:30+00:00
# 4 2023-11-29 14:00:33+00:00
#
#                                                title  \
# 0  TEKKEN 8 – THE RETURN OF LEGENDS - NEW CHARACT...
# 1  TEKKEN 8 – Victor Chevalier Reveal & Gameplay ...
# 2         TEKKEN 8 — Reina Reveal & Gameplay Trailer
# 3           TEKKEN 8 — Leo Reveal & Gameplay Trailer
# 4     TEKKEN 8 – Steve Fox Reveal & Gameplay Trailer
#
#                                          description  \
# 0  Five legends return in #TEKKEN8 for the next K...
# 1  With him, violence is à la carte.\nVictor Chev...
# 2  It's time for them to learn their place.\nRein...
# 3  It's time to punch the truth out of them. Leo ...
# 4  Time to knock out the competition🥊\nSteve will...
#
#                                                 tags  viewCount  likeCount  \
# 0  [Bandai Namco, Bandai Namco Entertainment, Vid...     867742      24594
# 1  [Bandai Namco, Bandai Namco Entertainment, Vid...    1323861      42404
# 2  [Bandai Namco, Bandai Namco Entertainment, Vid...    1889054      57275
# 3  [Bandai Namco, Bandai Namco Entertainment, Vid...     822329      32381
# 4  [Bandai Namco, Bandai Namco Entertainment, Vid...     915840      37277
#
#    commentCount  favoriteCount
# 0          2809              0
# 1          7289              0
# 2          7538              0
# 3          5153              0
# 4          4430              0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   channelTitle   11 non-null     object
#  1   channelId      11 non-null     object
#  2   videoId        11 non-null     object
#  3   publishedAt    11 non-null     datetime64[ns, UTC]
#  4   title          11 non-null     object
#  5   description    11 non-null     object
#  6   tags           11 non-null     object
#  7   viewCount      11 non-null     int64
#  8   likeCount      11 non-null     int64
#  9   commentCount   11 non-null     int64
#  10  favoriteCount  11 non-null     int64
# dtypes: datetime64[ns, UTC](1), int64(4), object(6)
# memory usage: 1.1+ KB

# %%
pd.set_option('display.max_colwidth', None)
df.loc[:][["title", "commentCount", "videoId"]]
# Out:
#                                                                title  \
# 0   TEKKEN 8 – THE RETURN OF LEGENDS - NEW CHARACTERS REVEAL TRAILER
# 1              TEKKEN 8 – Victor Chevalier Reveal & Gameplay Trailer
# 2                         TEKKEN 8 — Reina Reveal & Gameplay Trailer
# 3                           TEKKEN 8 — Leo Reveal & Gameplay Trailer
# 4                     TEKKEN 8 – Steve Fox Reveal & Gameplay Trailer
# 5                      TEKKEN 8 — Dragunov Reveal & Gameplay Trailer
# 6                    TEKKEN 8 — Yoshimitsu Reveal & Gameplay Trailer
# 7                             TEKKEN 8 Exclusive Story Demo Showcase
# 8                                  TEKKEN 8 – Official Story Trailer
# 9                                TEKKEN 8 – Ultimate Edition Trailer
# 10                      TEKKEN 8 – Shaheen Reveal & Gameplay Trailer
#
#     commentCount      videoId
# 0           2809  rDxrpSqYHD8
# 1           7289  cIDK50IaVpg
# 2           7538  PsCpewoF2E4
# 3           5153  QH6s_o3dIic
# 4           4430  Zc-yMi05vBA
# 5           3290  ucesGynb2Yk
# 6           4815  y8JGUIF2pu4
# 7            361  9D5vq-zq9y4
# 8           4038  ToKJfywbe1o
# 9           1219  9jJiNa4HoD0
# 10          3685  UgnPG2bScVQ

# %% [markdown]
# I want to perform NLP work on the '_Ultimate Edition Trailer_' video, which has 1,218 comments..

# %% [markdown]
# # Get comments

# %% [markdown]
# ### Access the video ID I want comments from

# %%
df.loc[df["title"].str.lower().str.contains("tekken") & 
df["title"].str.lower().str.contains("ultimate edition")][["title", "videoId"]]
# Out:
#                                  title      videoId
# 9  TEKKEN 8 – Ultimate Edition Trailer  9jJiNa4HoD0

# %%
# filter dataframe to get only the row with the ultimate edition trailer video
df_filtered = df.loc[df["title"].str.lower().str.contains("tekken") & 
df["title"].str.lower().str.contains("ultimate edition")]["videoId"]

# store the video id in a variable
ultimate_edition_trailer_id = df_filtered.iloc[0]
ultimate_edition_trailer_id
# Out:
# '9jJiNa4HoD0'

# %% [markdown]
# Start with getting the comments when I pass one video id to the request...

# %%
# make a request for one video id
request = youtube.commentThreads().list(
    part="snippet",
    videoId="9jJiNa4HoD0",  
    order="time",
    maxResults=50
)

response = request.execute()

comments = []

for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    comments.append([
        comment['videoId'],
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['updatedAt'],
        comment['likeCount'],
        item['snippet']['totalReplyCount'], # reply count not stored in same section of json response as all the others        
        comment['textDisplay']
    ])

next_page_token = response.get("nextPageToken", None)
more_pages = True
    
while more_pages == True:
    if next_page_token is None:
        more_pages = False

    else: 
        # make a request to the youtube api to get the next page results   
        request = youtube.commentThreads().list(
            part="snippet",
            videoId='9jJiNa4HoD0',
            order="time",
            maxResults=50,
            pageToken=next_page_token,
        )
        
        response = request.execute()

        # loop through response and store data about each video in a dictionary
        for item in response['items']:
            comment = item['snippet']['topLevelComment']['snippet']
            comments.append([
                comment['videoId'],
                comment['authorDisplayName'],
                comment['publishedAt'],
                comment['updatedAt'],
                comment['likeCount'],
                item['snippet']['totalReplyCount'], # reply count not stored in same section of json response as all the others        
                comment['textDisplay']
            ])

        
        next_page_token = response.get("nextPageToken", None)



df_one_video = (pd.DataFrame(data=comments, columns=['videoId', 'authorDisplayName', 'publishedAt', 'updatedAt', 
                                          'likeCount', 'totalReplyCount', 'textDisplay'])
                .astype({"publishedAt": "datetime64[ns, UTC]", 
                         "updatedAt": "datetime64[ns, UTC]", 
                         "likeCount": "int64", 
                         "totalReplyCount": "int64"})
                .drop_duplicates(subset=["textDisplay"])
                .sort_values(by=["publishedAt"])
                .reset_index(drop=True)
               )


df_one_video.head(5)
# Out:
#        videoId   authorDisplayName               publishedAt  \
# 0  9jJiNa4HoD0  @aladdinleader1116 2023-12-19 14:00:38+00:00
# 1  9jJiNa4HoD0          @Awoken777 2023-12-19 14:01:03+00:00
# 2  9jJiNa4HoD0        @gagagag7051 2023-12-19 14:01:21+00:00
# 3  9jJiNa4HoD0      @UmoralCaratol 2023-12-19 14:01:23+00:00
# 4  9jJiNa4HoD0         @KodaiVibes 2023-12-19 14:01:26+00:00
#
#                   updatedAt  likeCount  totalReplyCount  \
# 0 2023-12-19 14:00:38+00:00          1                0
# 1 2023-12-19 14:01:03+00:00        611               81
# 2 2023-12-19 14:01:21+00:00          0                0
# 3 2023-12-19 14:01:23+00:00          1                0
# 4 2023-12-19 14:01:26+00:00          0                0
#
#                                                              textDisplay
# 0                                                              Wow🎉🎉🎉🎉🎉❤
# 1  Tekken is literally the only Game i would buy an ultimate edition for
# 2                                                                  First
# 3                                                               Clowning
# 4              UGH I WANT IT SOOOO BADDD, I NEED TO FIND A NEW JOB QUICK

# %%
response
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': '2jmBff-VdzS5GIF2IdMu4hRR1FA',
#  'pageInfo': {'totalResults': 20, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': '4flwgWNqi8T6pPaDgQiwFIc-_Yw',
#    'id': 'Ugyd8jlTPlSrq939sfl4AaABAg',
#    'snippet': {'channelId': 'UC_ntXHv-XdKCD7CPynVvnQw',
#     'videoId': '9jJiNa4HoD0',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'zOHCs7REjITCmO-2lYfRN3B_1Kg',
#      'id': 'Ugyd8jlTPlSrq939sfl4AaABAg',
#      'snippet': {'channelId': 'UC_ntXHv-XdKCD7CPynVvnQw',
#       'videoId': '9jJiNa4HoD0',
#       'textDisplay': 'this is the only reason to buy a ps5 for me',
#       'textOriginal': 'this is the only reason to buy a ps5 for me',
#       'authorDisplayName': '@riccardoripiccini5880',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIf8zZTH3CkWJlnkkD8YCMEg9JoGvm-KiJhle66GKLQy=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC7wA8PR4LmqhA9gsfFAKDDg',
#       'authorChannelId': {'value': 'UC7wA8PR4LmqhA9gsfFAKDDg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-12-19T14:02:49Z',
#       'updatedAt': '2023-12-19T14:02:49Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '8EFzpvOoq1hW9nnyWOJKo1blqCY',
#    'id': 'Ugyk59yszZYpZQNElWl4AaABAg',
#    'snippet': {'channelId': 'UC_ntXHv-XdKCD7CPynVvnQw',
#     'videoId': '9jJiNa4HoD0',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'SoUY--NpXBF6DG_kXgww9xUpHPE',
#      'id': 'Ugyk59yszZYpZQNElWl4AaABAg',
#      'snippet': {'channelId': 'UC_ntXHv-XdKCD7CPynVvnQw',
#       'videoId': '9jJiNa4HoD0',
#       'textDisplay': 'Nice golden suits for everyone. Already done.😇',
#       'textOriginal': 'Nice golden suits for everyone. Already done.😇',
#       'authorDisplayName': '@tekkenkasur',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIf8zZR1NZsi_MMTmj4N0PKz8P2dRLzFIH6J2h1qG839yA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCcjxgnX2TgbpJZSC1bJpDJA',
#       'authorChannelId': {'value': 'UCcjxgnX2TgbpJZSC1bJpDJA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2023-12-19T14:02:46Z',
#       'updatedAt': '2023-12-19T14:02:46Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'h919n8YEiE_FCLTbYw_HO2r1-GA',
#    'id': 'Ugy0JoHEcpkQ3GRHudx4AaABAg',
#    'snippet': {'channelId': 'UC_ntXHv-XdKCD7CPynVvnQw',
#     'videoId': '9jJiNa4HoD0',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'R5TSXDxYyrnr-_cJZ93PuhSddZQ',
#      'id': 'Ugy0JoHEcpkQ3GRHudx4AaABAg',
#      'snippet': {'channelId': 'UC_ntXHv-XdKCD7CPynVvnQw',
#       'videoId': '9jJiNa4HoD0',
#       'textDisplay': 'Clicked fast lol',
#       'textOriginal': 'Clicked fast lol',
#       'authorDisplayName': '@KanieI_Outis',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/AyXobHpJuS_coTNihmB2boszuP9vGCbuugtIVwRQZGtmK287yBzQ6Vaq7YX7ymeG7650cDXHgA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCNyM7aWK94YnCjoqLwBidsA',
#       'authorChannelId': {'value': 'UCNyM7aWK94YnCjoqLwBidsA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-12-19T14:02:41Z',
#       'updatedAt': '2023-12-19T14:02:41Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'Itu6zGzfRRhCnlIn5fB9d0gOhCo',
#    'id': 'UgxCQCDS6jLQB_thLR94AaABAg',
#    'snippet': {'channelId': 'UC_ntXHv-XdKCD7CPynVvnQw',
#     'videoId': '9jJiNa4HoD0',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'gycLXe_MpG-l3HLueXKzY2WUaT4',
#      'id': 'UgxCQCDS6jLQB_thLR94AaABAg',
#      'snippet': {'channelId': 'UC_ntXHv-XdKCD7CPynVvnQw',
#       'videoId': '9jJiNa4HoD0',
#       'textDisplay': 'Please release the dlc characters and i hop that anna and julia will be there in season 1',
#       'textOriginal': 'Please release the dlc characters and i hop that anna and julia will be there in season 1',
#       'authorDisplayName': '@Melodyline536',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/esdCDbAxF1OL99qd463suzVh2z4I5eE7jyEF0Ra9eEYKHDPIO9kNMYzXAmEA4LmVGimO08Ia=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCZKZf0E-7fYR-HdSTWW2CPg',
#       'authorChannelId': {'value': 'UCZKZf0E-7fYR-HdSTWW2CPg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 7,
#       'publishedAt': '2023-12-19T14:02:40Z',
#       'updatedAt': '2023-12-19T14:02:40Z'}},
#     'canReply': True,
#     'totalReplyCount': 10,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '25UVQQmQlO_xpf53oMeZCO0IQ5A',
#    'id': 'UgxHpTXS4b_l93J9lyd4AaABAg',
#    'snippet': {'channelId': 'UC_ntXHv-XdKCD7CPynVvnQw',
#     'videoId': '9jJiNa4HoD0',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'skf1HecbSVXtFI_q4Am_xYKRqu4',
#      'id': 'UgxHpTXS4b_l93J9lyd4AaABAg',
#      'snippet': {'channelId': 'UC_ntXHv-XdKCD7CPynVvnQw',
#       'videoId': '9jJiNa4HoD0',
#       'textDisplay': 'Opens with Kazuya&#39;s T7 intro which is actually a reference to the T6 intro 😅 Good job Namco, Giving the beat character and OG Protagonist his rightful recognition.',
#       'textOriginal': "Opens with Kazuya's T7 intro which is actually a reference to the T6 intro 😅 Good job Namco, Giving the beat character and OG Protagonist his rightful recognition.",
#       'authorDisplayName': '@otdreamer193-xy1uc',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/mOjOXA9XBW_nX_84Ga-8ZCGmj84hfvSp8eF5oeNYx4dIsMN5KaVvMk6fIyNhQrBr0tXJIKeuZw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCSIKeOV9fNNE9Yo8cDSTUoQ',
#       'authorChannelId': {'value': 'UCSIKeOV9fNNE9Yo8cDSTUoQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 7,
#       'publishedAt': '2023-12-19T14:02:30Z',
#       'updatedAt': '2023-12-19T14:02:30Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'g3oW6JIGo_20zxLIPB_HhM8q7W0',
#    'id': 'Ugzr1yr1nvPZY5siCth4AaABAg',
#    'snippet': {'channelId': 'UC_ntXHv-XdKCD7CPynVvnQw',
#     'videoId': '9jJiNa4HoD0',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'tfdYFziyU9jlBuVeQuwt2h_D7Og',
#      'id': 'Ugzr1yr1nvPZY5siCth4AaABAg',
#      'snippet': {'channelId': 'UC_ntXHv-XdKCD7CPynVvnQw',
#       'videoId': '9jJiNa4HoD0',
#       'textDisplay': 'Nah, dude, unless that dlc holds the devil gene or some Mishima sweat, I&#39;m sticking with standard edition',
#       'textOriginal': "Nah, dude, unless that dlc holds the devil gene or some Mishima sweat, I'm sticking with standard edition",
#       'authorDisplayName': '@stephenrios475',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIf8zZS4ifjR9FNrFboN3XJJT6GHSyg6YRo_QhAh25qtSg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCvV2jtqssrQ9Jrmhvy8uWhw',
#       'authorChannelId': {'value': 'UCvV2jtqssrQ9Jrmhvy8uWhw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 98,
#       'publishedAt': '2023-12-19T14:02:25Z',
#       'updatedAt': '2023-12-21T15:40:16Z'}},
#     'canReply': True,
#     'totalReplyCount': 6,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'MUP8t06CMPpEdIQAlhaBGCDKVns',
#    'id': 'UgwSk5AfhcPn0T2rbWl4AaABAg',
#    'snippet': {'channelId': 'UC_ntXHv-XdKCD7CPynVvnQw',
#     'videoId': '9jJiNa4HoD0',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '_kQBQw7hFObN_JTLDDBh4lr4AXo',
#      'id': 'UgwSk5AfhcPn0T2rbWl4AaABAg',
#      'snippet': {'channelId': 'UC_ntXHv-XdKCD7CPynVvnQw',
#       'videoId': '9jJiNa4HoD0',
#       'textDisplay': 'Honestly, seeing how dripped out everyone is, I doubt anyone is going to want to play with that suit.',
#       'textOriginal': 'Honestly, seeing how dripped out everyone is, I doubt anyone is going to want to play with that suit.',
#       'authorDisplayName': '@moises.m',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/Uc9sUmcqN1PoO3_RFMxGAWzSp5_WL0ZCO97KgsTlpZkYCI_G7kHUj3HEMR3gVkyZQXx-4u2t6Q=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCwXBG71fYucRddOGFD4VorA',
#       'authorChannelId': {'value': 'UCwXBG71fYucRddOGFD4VorA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 13,
#       'publishedAt': '2023-12-19T14:02:19Z',
#       'updatedAt': '2023-12-19T14:02:19Z'}},
#     'canReply': True,
#     'totalReplyCount': 3,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'mg3sznkKZHsVUIRq1oa4aLBDuOU',
#    'id': 'UgweBWaXyRg1J4rzt1l4AaABAg',
#    'snippet': {'channelId': 'UC_ntXHv-XdKCD7CPynVvnQw',
#     'videoId': '9jJiNa4HoD0',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'G1L_uQQrXZWfoeYTRx40ph-Wnnk',
#      'id': 'UgweBWaXyRg1J4rzt1l4AaABAg',
#      'snippet': {'channelId': 'UC_ntXHv-XdKCD7CPynVvnQw',
#       'videoId': '9jJiNa4HoD0',
#       'textDisplay': 'Gonna order',
#       'textOriginal': 'Gonna order',
#       'authorDisplayName': '@abdultahir955',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIf8zZSdUq9qlk0_bQDF5GooT-MRKjeTWFWLVFwumQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCVG8nBr3nn6ZlFCeZof0e9A',
#       'authorChannelId': {'value': 'UCVG8nBr3nn6ZlFCeZof0e9A'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-12-19T14:02:13Z',
#       'updatedAt': '2023-12-19T14:02:13Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'Ft28C6uG7T9cjY1mqJmrKd2aoAI',
#    'id': 'UgwbGe2UdR2JxwadQw14AaABAg',
#    'snippet': {'channelId': 'UC_ntXHv-XdKCD7CPynVvnQw',
#     'videoId': '9jJiNa4HoD0',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '2cjzoineeaSEQ4iR9RbXtNg9oK0',
#      'id': 'UgwbGe2UdR2JxwadQw14AaABAg',
#      'snippet': {'channelId': 'UC_ntXHv-XdKCD7CPynVvnQw',
#       'videoId': '9jJiNa4HoD0',
#       'textDisplay': 'I cant wait to pre order it',
#       'textOriginal': 'I cant wait to pre order it',
#       'authorDisplayName': '@kazamataurus337',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIf8zZRl6vmQyqB9TnThvRvL_hXjXXf3Eu9Tt_hdjTgGHg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCBfGAxZycMq4uHlpoTXUXfQ',
#       'authorChannelId': {'value': 'UCBfGAxZycMq4uHlpoTXUXfQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 3,
#       'publishedAt': '2023-12-19T14:02:11Z',
#       'updatedAt': '2023-12-19T14:02:11Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '4AP-q1hkYTHwYmdf2b1OMhXJHOA',
#    'id': 'UgxijihDNWVNLnExY4B4AaABAg',
#    'snippet': {'channelId': 'UC_ntXHv-XdKCD7CPynVvnQw',
#     'videoId': '9jJiNa4HoD0',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'g5rACo1aIotcAzCvZTdOSWTMUg8',
#      'id': 'UgxijihDNWVNLnExY4B4AaABAg',
#      'snippet': {'channelId': 'UC_ntXHv-XdKCD7CPynVvnQw',
#       'videoId': '9jJiNa4HoD0',
#       'textDisplay': 'can we change the color of the avatar skin outfits?',
#       'textOriginal': 'can we change the color of the avatar skin outfits?',
#       'authorDisplayName': '@Mslingsler',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/IYYdSM2wiI1njt-0AkcJjnbdu7AOgjVJeLvbxYO3BB1M7G3UxualfBM4CVU1e88hTOjiVCpdvQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC6xMrhD9KiayNvL8-57PeWw',
#       'authorChannelId': {'value': 'UC6xMrhD9KiayNvL8-57PeWw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2023-12-19T14:02:04Z',
#       'updatedAt': '2023-12-19T14:02:04Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'LWRBFMNmmcGIDcApXICw6kNHVf4',
#    'id': 'Ugx9LTUoHQWRdbXsRM94AaABAg',
#    'snippet': {'channelId': 'UC_ntXHv-XdKCD7CPynVvnQw',
#     'videoId': '9jJiNa4HoD0',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'n3zZpI2yqkjNiPwbdvdBbCdOAn8',
#      'id': 'Ugx9LTUoHQWRdbXsRM94AaABAg',
#      'snippet': {'channelId': 'UC_ntXHv-XdKCD7CPynVvnQw',
#       'videoId': '9jJiNa4HoD0',
#       'textDisplay': 'The best fighting game everrrrr',
#       'textOriginal': 'The best fighting game everrrrr',
#       'authorDisplayName': '@theenlightenedone1283',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIf8zZTDpYgV9PXg5d4ZX_JyIEMISbfVCgOWXAMQYg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCU04iI5hnZSwLfIkAu5mCuw',
#       'authorChannelId': {'value': 'UCU04iI5hnZSwLfIkAu5mCuw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 2,
#       'publishedAt': '2023-12-19T14:01:58Z',
#       'updatedAt': '2023-12-19T14:01:58Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'xsORpoxy1aZw_92qcz-w-xciTxg',
#    'id': 'UgzgGkyOUF7pifKCVu54AaABAg',
#    'snippet': {'channelId': 'UC_ntXHv-XdKCD7CPynVvnQw',
#     'videoId': '9jJiNa4HoD0',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '6tgK3Ft8_CVpNe0cmbT91wwQMRo',
#      'id': 'UgzgGkyOUF7pifKCVu54AaABAg',
#      'snippet': {'channelId': 'UC_ntXHv-XdKCD7CPynVvnQw',
#       'videoId': '9jJiNa4HoD0',
#       'textDisplay': 'We need the next trailer 🙂',
#       'textOriginal': 'We need the next trailer 🙂',
#       'authorDisplayName': '@mohannedzwil424',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIf8zZSYyE-yaa-j9cU5CGZuZvRO3aoHgw96cBSSew=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCHTKBZw8MnOeXqhqHKZIq9w',
#       'authorChannelId': {'value': 'UCHTKBZw8MnOeXqhqHKZIq9w'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 62,
#       'publishedAt': '2023-12-19T14:01:48Z',
#       'updatedAt': '2023-12-19T14:01:48Z'}},
#     'canReply': True,
#     'totalReplyCount': 10,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'SCdTd4WSM8jAYnsNWHhhk4u2b60',
#    'id': 'UgxfWjHYqCVnd-U_9np4AaABAg',
#    'snippet': {'channelId': 'UC_ntXHv-XdKCD7CPynVvnQw',
#     'videoId': '9jJiNa4HoD0',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '-M3e-E-FfPVEDCMUfkSuZzl0aec',
#      'id': 'UgxfWjHYqCVnd-U_9np4AaABAg',
#      'snippet': {'channelId': 'UC_ntXHv-XdKCD7CPynVvnQw',
#       'videoId': '9jJiNa4HoD0',
#       'textDisplay': 'THANK YOU TEKKEN!',
#       'textOriginal': 'THANK YOU TEKKEN!',
#       'authorDisplayName': '@KodaiVibes',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIf8zZQp6J9tJs9fN64WNCpE1A119x19UmGUihaFcUP8sw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCbHiNSoxgkfUzNFcjTLZeQA',
#       'authorChannelId': {'value': 'UCbHiNSoxgkfUzNFcjTLZeQA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 5,
#       'publishedAt': '2023-12-19T14:01:39Z',
#       'updatedAt': '2023-12-19T14:01:39Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'oGRJT3iEmntkvh9HJu4Wk27SiDc',
#    'id': 'Ugz8nSUtMHktlIEpcAl4AaABAg',
#    'snippet': {'channelId': 'UC_ntXHv-XdKCD7CPynVvnQw',
#     'videoId': '9jJiNa4HoD0',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '9OLEFvrc3oShDUiFAawGOJQIJyg',
#      'id': 'Ugz8nSUtMHktlIEpcAl4AaABAg',
#      'snippet': {'channelId': 'UC_ntXHv-XdKCD7CPynVvnQw',
#       'videoId': '9jJiNa4HoD0',
#       'textDisplay': 'The game is not our yet and we&#39;re already getting paid dlc 💀',
#       'textOriginal': "The game is not our yet and we're already getting paid dlc 💀",
#       'authorDisplayName': '@chloesmurf',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/nDtQbyqwYswOcMF4WDU5cYfrN_YL7uFSPIo1nBlv3vTJgYotoaNegpdB2z36kjXRlOHz2_ud=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCNu_AXo_vAf5wPOIPQKjGgw',
#       'authorChannelId': {'value': 'UCNu_AXo_vAf5wPOIPQKjGgw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 6,
#       'publishedAt': '2023-12-19T14:01:33Z',
#       'updatedAt': '2023-12-19T14:01:33Z'}},
#     'canReply': True,
#     'totalReplyCount': 2,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'dkxg8I8SYUIqjCKv3IEUK2jw-8A',
#    'id': 'UgwXCDO0qEZnuDHdKWF4AaABAg',
#    'snippet': {'channelId': 'UC_ntXHv-XdKCD7CPynVvnQw',
#     'videoId': '9jJiNa4HoD0',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'hNr6TR6MY7GdHw9SSrDHcup0ZkI',
#      'id': 'UgwXCDO0qEZnuDHdKWF4AaABAg',
#      'snippet': {'channelId': 'UC_ntXHv-XdKCD7CPynVvnQw',
#       'videoId': '9jJiNa4HoD0',
#       'textDisplay': 'This is gonna be a Goated Game',
#       'textOriginal': 'This is gonna be a Goated Game',
#       'authorDisplayName': '@catrina45454',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/hitynvIstpyqBP7vzoqD8oiAgWf1VN-mfq2JGQ8sHPCXxEvN7PAA_Tm79Pitu4P6aDn4gUse-A=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC8rc1Fa2dWTqd7aeAiMoQQg',
#       'authorChannelId': {'value': 'UC8rc1Fa2dWTqd7aeAiMoQQg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 8,
#       'publishedAt': '2023-12-19T14:01:29Z',
#       'updatedAt': '2023-12-19T14:01:29Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'GCNjbMekIHr9YCDqIIZnyvJHdlo',
#    'id': 'Ugxi3FzXwHOoNhI1AGt4AaABAg',
#    'snippet': {'channelId': 'UC_ntXHv-XdKCD7CPynVvnQw',
#     'videoId': '9jJiNa4HoD0',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'wtStdsXqjuXRh08w5eUP5RoFnZw',
#      'id': 'Ugxi3FzXwHOoNhI1AGt4AaABAg',
#      'snippet': {'channelId': 'UC_ntXHv-XdKCD7CPynVvnQw',
#       'videoId': '9jJiNa4HoD0',
#       'textDisplay': 'UGH I WANT IT SOOOO BADDD, I NEED TO FIND A NEW JOB QUICK',
#       'textOriginal': 'UGH I WANT IT SOOOO BADDD, I NEED TO FIND A NEW JOB QUICK',
#       'authorDisplayName': '@KodaiVibes',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIf8zZQp6J9tJs9fN64WNCpE1A119x19UmGUihaFcUP8sw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCbHiNSoxgkfUzNFcjTLZeQA',
#       'authorChannelId': {'value': 'UCbHiNSoxgkfUzNFcjTLZeQA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-12-19T14:01:26Z',
#       'updatedAt': '2023-12-19T14:01:26Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'Erj9UQAHR0mOg7ZFoPOC5K8x9ro',
#    'id': 'UgwqCYI4_VOCmPSY9Vd4AaABAg',
#    'snippet': {'channelId': 'UC_ntXHv-XdKCD7CPynVvnQw',
#     'videoId': '9jJiNa4HoD0',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'qrpMvHVruxmSIbO58PBeFD76FXA',
#      'id': 'UgwqCYI4_VOCmPSY9Vd4AaABAg',
#      'snippet': {'channelId': 'UC_ntXHv-XdKCD7CPynVvnQw',
#       'videoId': '9jJiNa4HoD0',
#       'textDisplay': 'Clowning',
#       'textOriginal': 'Clowning',
#       'authorDisplayName': '@UmoralCaratol',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/_AfofMeLefbg5WjyDLvOBSGg3iSBtyjQgtewYgC_RcO3Jtm3ROhvXGO3necajH-wZUn3thvf=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCoEn0uaMm2a0Oya5Xo3OIhw',
#       'authorChannelId': {'value': 'UCoEn0uaMm2a0Oya5Xo3OIhw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2023-12-19T14:01:23Z',
#       'updatedAt': '2023-12-19T14:01:23Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'YEqYZ9Ek6HOGmWJ6h9gbAvsBrTk',
#    'id': 'UgzismlcsPmkQ9XcSA94AaABAg',
#    'snippet': {'channelId': 'UC_ntXHv-XdKCD7CPynVvnQw',
#     'videoId': '9jJiNa4HoD0',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'OzY_sfns2tGBkjFtjNIGzO29KrI',
#      'id': 'UgzismlcsPmkQ9XcSA94AaABAg',
#      'snippet': {'channelId': 'UC_ntXHv-XdKCD7CPynVvnQw',
#       'videoId': '9jJiNa4HoD0',
#       'textDisplay': 'First',
#       'textOriginal': 'First',
#       'authorDisplayName': '@gagagag7051',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIf8zZSuzj84pgKgeCDHU7yfBRT1jr-0CrIJo2GhK-yBxg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCZE8MY7HCpU_85IpaCgL4cA',
#       'authorChannelId': {'value': 'UCZE8MY7HCpU_85IpaCgL4cA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-12-19T14:01:21Z',
#       'updatedAt': '2023-12-19T14:01:21Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'ppqEUhOy-WQrCToHErcm2thpFG8',
#    'id': 'Ugxcfh-cfIbMqpiS-al4AaABAg',
#    'snippet': {'channelId': 'UC_ntXHv-XdKCD7CPynVvnQw',
#     'videoId': '9jJiNa4HoD0',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '2rPnqwVvIk3T41nFUlSYWLkotc4',
#      'id': 'Ugxcfh-cfIbMqpiS-al4AaABAg',
#      'snippet': {'channelId': 'UC_ntXHv-XdKCD7CPynVvnQw',
#       'videoId': '9jJiNa4HoD0',
#       'textDisplay': 'Tekken is literally the only Game i would buy an ultimate edition for',
#       'textOriginal': 'Tekken is literally the only Game i would buy an ultimate edition for',
#       'authorDisplayName': '@Awoken777',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/J_A9yAW8Dt50zqpC22-rXrpQ1D4i7Uo6cZvo88CO8nRnKmUZvPq4YWf6gIcLYK8evhfSc2DF=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCoL9Fmy2qFsBsIYyTNQtLXw',
#       'authorChannelId': {'value': 'UCoL9Fmy2qFsBsIYyTNQtLXw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 611,
#       'publishedAt': '2023-12-19T14:01:03Z',
#       'updatedAt': '2023-12-19T14:01:03Z'}},
#     'canReply': True,
#     'totalReplyCount': 81,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '5vO5XH3NY7i-DZcZnLOhnKb4iwk',
#    'id': 'Ugzb6BiYJQnTwfpiASd4AaABAg',
#    'snippet': {'channelId': 'UC_ntXHv-XdKCD7CPynVvnQw',
#     'videoId': '9jJiNa4HoD0',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'Msii9vbOK3eb9pNkea4PhPuaOt8',
#      'id': 'Ugzb6BiYJQnTwfpiASd4AaABAg',
#      'snippet': {'channelId': 'UC_ntXHv-XdKCD7CPynVvnQw',
#       'videoId': '9jJiNa4HoD0',
#       'textDisplay': 'Wow🎉🎉🎉🎉🎉❤',
#       'textOriginal': 'Wow🎉🎉🎉🎉🎉❤',
#       'authorDisplayName': '@aladdinleader1116',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIf8zZRmfeU8KJ-HgAqlmC9TUIE8LnlSgjAOBVEnOPk=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCl1q1QWhmBZrQg3FDAY4LeA',
#       'authorChannelId': {'value': 'UCl1q1QWhmBZrQg3FDAY4LeA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2023-12-19T14:00:38Z',
#       'updatedAt': '2023-12-19T14:00:38Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}}]}

# %%
df_one_video.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   videoId            768 non-null    object
#  1   authorDisplayName  768 non-null    object
#  2   publishedAt        768 non-null    datetime64[ns, UTC]
#  3   updatedAt          768 non-null    datetime64[ns, UTC]
#  4   likeCount          768 non-null    int64
#  5   totalReplyCount    768 non-null    int64
#  6   textDisplay        768 non-null    object
# dtypes: datetime64[ns, UTC](2), int64(2), object(3)
# memory usage: 42.1+ KB

# %%
# export to csv
df_one_video.to_csv("data/raw/ultimate_edition_trailer_comments.csv", index=False)

# %% [markdown]
# # Get comments function

# %%
def get_top_level_comments(youtube_service_object, video_ids):
    """Retrieves the commentThreads for a given YouTube video ID or list of video IDs.

    Parameters
    ----------
    video_ids : list or str
        A list of video IDs or a single string if only wanting to return data for one video ID.

    Returns
    --------
    df : dataframe
        A dataframe with the top level comments for the video ID.
    
    """

    # check if the video_ids input is a single string or list
    if isinstance(video_ids, str):
        video_ids = [video_ids]
  
    
    comments = []
    
    # loop through the remaining video ids, get the comments for these videos
    for index, video_id in enumerate(video_ids): 
        # make a request for first video id
        request = youtube_service_object.commentThreads().list(
            part="snippet",
            videoId=video_id,  
            order="time",
            maxResults=50
        )
        
        response = request.execute()
        
        for item in response['items']:
            comment = item['snippet']['topLevelComment']['snippet']
            comments.append([
                comment['videoId'],
                comment['authorDisplayName'],
                comment['publishedAt'],
                comment['updatedAt'],
                comment['likeCount'],
                item['snippet']['totalReplyCount'], # reply count not stored in same section of json response as all the others        
                comment['textDisplay']
            ])
        
        next_page_token = response.get("nextPageToken", None)
        more_pages = True
            
        while more_pages == True:
            if next_page_token is None:
                more_pages = False
        
            else: 
                # make a request to the youtube api to get the next page results   
                request = youtube_service_object.commentThreads().list(
                    part="snippet",
                    videoId=video_id,
                    order="time",
                    maxResults=50,
                    pageToken=next_page_token,
                )
                
                response = request.execute()
        
                # loop through response and store data about each video in a dictionary
                for item in response['items']:
                    comment = item['snippet']['topLevelComment']['snippet']
                    comments.append([
                        comment['videoId'],
                        comment['authorDisplayName'],
                        comment['publishedAt'],
                        comment['updatedAt'],
                        comment['likeCount'],
                        item['snippet']['totalReplyCount'], # reply count not stored in same section of json response as all the others        
                        comment['textDisplay']
                    ])
        
                
                next_page_token = response.get("nextPageToken", None)         
    
        
        
        df = (pd.DataFrame(data=comments, columns=['videoId', 'authorDisplayName', 'publishedAt', 'updatedAt', 
                                                  'likeCount', 'totalReplyCount', 'textDisplay'])
                        .astype({"publishedAt": "datetime64[ns, UTC]", 
                                 "updatedAt": "datetime64[ns, UTC]", 
                                 "likeCount": "int64", 
                                 "totalReplyCount": "int64"})
                        .drop_duplicates(subset=["textDisplay"])
                        .sort_values(by=["publishedAt"])
                        .reset_index(drop=True)
                       )
    
    
    return df

# %% [markdown]
# # Test function

# %% [markdown]
# ## Test - One video ID

# %%
# test with one id
df_test = get_top_level_comments(youtube_service_object=youtube, video_ids=ultimate_edition_trailer_id)
df_test.head()
# Out:
#        videoId   authorDisplayName               publishedAt  \
# 0  9jJiNa4HoD0  @aladdinleader1116 2023-12-19 14:00:38+00:00
# 1  9jJiNa4HoD0          @Awoken777 2023-12-19 14:01:03+00:00
# 2  9jJiNa4HoD0        @gagagag7051 2023-12-19 14:01:21+00:00
# 3  9jJiNa4HoD0      @UmoralCaratol 2023-12-19 14:01:23+00:00
# 4  9jJiNa4HoD0         @KodaiVibes 2023-12-19 14:01:26+00:00
#
#                   updatedAt  likeCount  totalReplyCount  \
# 0 2023-12-19 14:00:38+00:00          1                0
# 1 2023-12-19 14:01:03+00:00        611               81
# 2 2023-12-19 14:01:21+00:00          0                0
# 3 2023-12-19 14:01:23+00:00          1                0
# 4 2023-12-19 14:01:26+00:00          0                0
#
#                                                              textDisplay
# 0                                                              Wow🎉🎉🎉🎉🎉❤
# 1  Tekken is literally the only Game i would buy an ultimate edition for
# 2                                                                  First
# 3                                                               Clowning
# 4              UGH I WANT IT SOOOO BADDD, I NEED TO FIND A NEW JOB QUICK

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   videoId            768 non-null    object
#  1   authorDisplayName  768 non-null    object
#  2   publishedAt        768 non-null    datetime64[ns, UTC]
#  3   updatedAt          768 non-null    datetime64[ns, UTC]
#  4   likeCount          768 non-null    int64
#  5   totalReplyCount    768 non-null    int64
#  6   textDisplay        768 non-null    object
# dtypes: datetime64[ns, UTC](2), int64(2), object(3)
# memory usage: 42.1+ KB

# %% [markdown]
# ## Test - 3 video IDs

# %%
# test with 3 video ids
video_ids_3_test = ["9jJiNa4HoD0", "9D5vq-zq9y4", "rDxrpSqYHD8"]

df_3_videos_test = get_top_level_comments(youtube_service_object=youtube, video_ids=video_ids_3_test)
df_3_videos_test.head()
# Out:
#        videoId  authorDisplayName               publishedAt  \
# 0  rDxrpSqYHD8       @silveriver9 2023-11-01 16:09:58+00:00
# 1  rDxrpSqYHD8  @faizaanjaved7150 2023-11-01 16:10:05+00:00
# 2  rDxrpSqYHD8          @TS-rw4lk 2023-11-01 16:10:05+00:00
# 3  rDxrpSqYHD8           @ALONCAK 2023-11-01 16:10:06+00:00
# 4  rDxrpSqYHD8   @Rough_Estimates 2023-11-01 16:10:06+00:00
#
#                   updatedAt  likeCount  totalReplyCount  \
# 0 2023-11-01 16:10:43+00:00          4                4
# 1 2023-11-01 16:10:05+00:00          1                1
# 2 2023-11-01 16:10:05+00:00          0                0
# 3 2023-11-01 16:10:06+00:00          0                0
# 4 2023-11-01 16:10:06+00:00        135               14
#
#                                              textDisplay
# 0                       First. Now where is LEI WULONG?!
# 1  Already seen it. Ur getting less view&#39;s now bamco
# 2                                                    wow
# 3                                              Oww yeaah
# 4                  I hope we get an angel version of Jin

# %%
df_3_videos_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3022 entries, 0 to 3021
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   videoId            3022 non-null   object
#  1   authorDisplayName  3022 non-null   object
#  2   publishedAt        3022 non-null   datetime64[ns, UTC]
#  3   updatedAt          3022 non-null   datetime64[ns, UTC]
#  4   likeCount          3022 non-null   int64
#  5   totalReplyCount    3022 non-null   int64
#  6   textDisplay        3022 non-null   object
# dtypes: datetime64[ns, UTC](2), int64(2), object(3)
# memory usage: 165.4+ KB

# %%
df_3_videos_test["videoId"].nunique()
# Out:
# 3

# %%
df_3_videos_test.to_csv("data/raw/comments_3_videos_test.csv", index=False)

# %% [markdown]
# ## Get comments for new characters reveal video

# %%
df.loc[:][["title", "commentCount", "videoId"]]
# Out:
#                                                                title  \
# 0   TEKKEN 8 – THE RETURN OF LEGENDS - NEW CHARACTERS REVEAL TRAILER
# 1              TEKKEN 8 – Victor Chevalier Reveal & Gameplay Trailer
# 2                         TEKKEN 8 — Reina Reveal & Gameplay Trailer
# 3                           TEKKEN 8 — Leo Reveal & Gameplay Trailer
# 4                     TEKKEN 8 – Steve Fox Reveal & Gameplay Trailer
# 5                      TEKKEN 8 — Dragunov Reveal & Gameplay Trailer
# 6                    TEKKEN 8 — Yoshimitsu Reveal & Gameplay Trailer
# 7                             TEKKEN 8 Exclusive Story Demo Showcase
# 8                                  TEKKEN 8 – Official Story Trailer
# 9                                TEKKEN 8 – Ultimate Edition Trailer
# 10                      TEKKEN 8 – Shaheen Reveal & Gameplay Trailer
#
#     commentCount      videoId
# 0           2809  rDxrpSqYHD8
# 1           7289  cIDK50IaVpg
# 2           7538  PsCpewoF2E4
# 3           5153  QH6s_o3dIic
# 4           4430  Zc-yMi05vBA
# 5           3290  ucesGynb2Yk
# 6           4815  y8JGUIF2pu4
# 7            361  9D5vq-zq9y4
# 8           4038  ToKJfywbe1o
# 9           1219  9jJiNa4HoD0
# 10          3685  UgnPG2bScVQ

# %%
# define video ids we want to get comments for
# filter dataframe to get only the row with the ultimate edition trailer video
df_filtered = df.loc[df["title"].str.lower().str.contains("characters reveal")]

df_filtered.head()
# Out:
#                          channelTitle                 channelId      videoId  \
# 0  Bandai Namco Entertainment America  UC_ntXHv-XdKCD7CPynVvnQw  rDxrpSqYHD8
#
#                 publishedAt  \
# 0 2023-11-01 16:09:18+00:00
#
#                                                               title  \
# 0  TEKKEN 8 – THE RETURN OF LEGENDS - NEW CHARACTERS REVEAL TRAILER
#
#                                                                                                                                                                                                                                                                                                                                                                     description  \
# 0  Five legends return in #TEKKEN8 for the next King of Iron Fist tournament!\n\nAnd we're not done yet. 👊 http://tekken.com\n\nTake a look at the latest fighters newly confirmed as playable in Tekken 8: Devil Jin, Zafina, Alisa Bosconovich, and Lee Chaolan (with a bonus appearance by Panda). The final characters will be revealed on November 2 and then November 12.
#
#                                                                                                                           tags  \
# 0  [Bandai Namco, Bandai Namco Entertainment, Video, Games, video games, namco bandai, United States, PS5, PS4, Xbox Series X]
#
#    viewCount  likeCount  commentCount  favoriteCount
# 0     867777      24594          2809              0

# %%
new_characters_reveal_id = df_filtered["videoId"][0]
new_characters_reveal_id
# Out:
# 'rDxrpSqYHD8'

# %%
df_new_character_reveal_comments = get_top_level_comments(youtube_service_object=youtube, video_ids=characters_revealed_id)
df_new_character_reveal_comments.head()
# Out:
#           videoId          authorDisplayName               publishedAt  \
# 0     rDxrpSqYHD8               @silveriver9 2023-11-01 16:09:58+00:00
# 1     rDxrpSqYHD8          @faizaanjaved7150 2023-11-01 16:10:05+00:00
# 2     rDxrpSqYHD8                  @TS-rw4lk 2023-11-01 16:10:05+00:00
# 3     rDxrpSqYHD8                   @ALONCAK 2023-11-01 16:10:06+00:00
# 4     rDxrpSqYHD8           @Rough_Estimates 2023-11-01 16:10:06+00:00
# ...           ...                        ...                       ...
# 2036  rDxrpSqYHD8  @muhammadrafaythaheem9731 2023-12-24 07:57:43+00:00
# 2037  rDxrpSqYHD8     @helikoptergezgini9728 2023-12-25 21:27:41+00:00
# 2038  rDxrpSqYHD8              @pureOwarrior 2023-12-26 19:34:16+00:00
# 2039  rDxrpSqYHD8                 @369dakuza 2023-12-27 20:24:12+00:00
# 2040  rDxrpSqYHD8          @backtobaking4054 2023-12-28 01:27:40+00:00
#
#                      updatedAt  likeCount  totalReplyCount  \
# 0    2023-11-01 16:10:43+00:00          4                4
# 1    2023-11-01 16:10:05+00:00          1                1
# 2    2023-11-01 16:10:05+00:00          0                0
# 3    2023-11-01 16:10:06+00:00          0                0
# 4    2023-11-01 16:10:06+00:00        135               14
# ...                        ...        ...              ...
# 2036 2023-12-24 07:57:43+00:00          0                0
# 2037 2023-12-25 21:27:41+00:00          0                0
# 2038 2023-12-26 19:34:16+00:00          0                0
# 2039 2023-12-27 20:24:12+00:00          0                0
# 2040 2023-12-28 01:27:40+00:00          0                0
#
#                                                                                                                                                                                                                                                     textDisplay
# 0                                                                                                                                                                                                                              First. Now where is LEI WULONG?!
# 1                                                                                                                                                                                                         Already seen it. Ur getting less view&#39;s now bamco
# 2                                                                                                                                                                                                                                                           wow
# 3                                                                                                                                                                                                                                                     Oww yeaah
# 4                                                                                                                                                                                                                         I hope we get an angel version of Jin
# ...                                                                                                                                                                                                                                                         ...
# 2036                                                                                                                                                                                                                                     Maaaarveroooosssse 🤣🤣🤣
# 2037  what you call new is in the game for almost all Tekken games. Are you kiddin me?!?! Nothin new here. Where is Eddy! Where are all the other great characters. I m just watching a sinking game. Too bad after Tekken 7 we got this. Its must be a joke...
# 2038                                                                                                                                                                                                                  Wished if this was Lee actual rage art :(
# 2039                                                                                                                     marduk? armor king? common... my mains aint in my main game? like wtf im not gonna buy until ltheir dlc come out.... very disappointed
# 2040                                                                                                                                                                                                                                                    Legends
#
# [2041 rows x 7 columns]

# %%
df_new_character_reveal_comments.to_csv("data/raw/new_character_reveal_comments.csv", index=False)
