# %%
import os
os.chdir('..') # this resolves ImportError: attempted relative import with no known parent package

# general DS packages
import pandas as pd
import numpy as np

# cleaning and pre-processing
from src.processing.text_cleaning import (normalize_text, process_contractions, remove_all_punctuation, remove_emojis, 
remove_html_unescape, remove_href_pattern, remove_digits, remove_extra_whitespace, remove_website_links)
from src.processing.text_processing import (tokenize_comment, lemmatize_comment, remove_stop_words, remove_tekken_character_names_from_tokens, 
part_of_speech, part_of_speech_tag, part_of_speech_dependency, part_of_speech_shape, part_of_speech_alpha, part_of_speech_is_stop)

# %%
# import data from csv
raw_data = pd.read_csv("data/raw/new_character_reveal_comments.csv", )
data = raw_data.copy()
df = pd.DataFrame(data)
df.head()
# Out:
#        videoId  authorDisplayName                publishedAt  \
# 0  rDxrpSqYHD8       @silveriver9  2023-11-01 16:09:58+00:00
# 1  rDxrpSqYHD8  @faizaanjaved7150  2023-11-01 16:10:05+00:00
# 2  rDxrpSqYHD8          @TS-rw4lk  2023-11-01 16:10:05+00:00
# 3  rDxrpSqYHD8           @ALONCAK  2023-11-01 16:10:06+00:00
# 4  rDxrpSqYHD8   @Rough_Estimates  2023-11-01 16:10:06+00:00
#
#                    updatedAt  likeCount  totalReplyCount  \
# 0  2023-11-01 16:10:43+00:00          4                4
# 1  2023-11-01 16:10:05+00:00          1                1
# 2  2023-11-01 16:10:05+00:00          0                0
# 3  2023-11-01 16:10:06+00:00          0                0
# 4  2023-11-01 16:10:06+00:00        135               14
#
#                                          textDisplay
# 0                   First. Now where is LEI WULONG?!
# 1  Already seen it. Ur getting less view&#39;s no...
# 2                                                wow
# 3                                          Oww yeaah
# 4              I hope we get an angel version of Jin

# %%
# %%time

# clean
df['textDisplay'] = df['textDisplay'].apply(normalize_text)
df['textDisplay'] = df['textDisplay'].apply(process_contractions)
df['textDisplay'] = df['textDisplay'].apply(remove_website_links)
df['textDisplay'] = df['textDisplay'].apply(remove_html_unescape)
df['textDisplay'] = df['textDisplay'].apply(remove_emojis)
df['textDisplay'] = df['textDisplay'].apply(remove_digits)
df['textDisplay'] = df['textDisplay'].apply(remove_all_punctuation)
df['textDisplay'] = df['textDisplay'].apply(remove_href_pattern)
df['textDisplay'] = df['textDisplay'].apply(remove_extra_whitespace)

# process
df["textStopWordsRemoved"] = df["textDisplay"].apply(remove_stop_words)
df["textTokenized"] = df['textStopWordsRemoved'].apply(tokenize_comment)
df["textLemmatized"] = df["textStopWordsRemoved"].apply(lemmatize_comment)
df["textTekkenCharactersRemoved"] = df["textLemmatized"].apply(remove_tekken_character_names_from_tokens)


# part of speech operations
(df["pos"], 
 df["posTag"],
 df["posDependency"],
 df["posShape"],
 df["posAlpha"],
 df["posStopWord"]) = (df["textStopWordsRemoved"].apply(part_of_speech),
                                 df["textStopWordsRemoved"].apply(part_of_speech_tag),
                                 df["textStopWordsRemoved"].apply(part_of_speech_dependency),
                                 df["textStopWordsRemoved"].apply(part_of_speech_shape),
                                 df["textStopWordsRemoved"].apply(part_of_speech_alpha),
                                 df["textStopWordsRemoved"].apply(part_of_speech_is_stop)
                                )
df.head()
# Out:
# CPU times: user 38.5 s, sys: 43.2 ms, total: 38.5 s
# Wall time: 38.7 s
#        videoId  authorDisplayName                publishedAt  \
# 0  rDxrpSqYHD8       @silveriver9  2023-11-01 16:09:58+00:00
# 1  rDxrpSqYHD8  @faizaanjaved7150  2023-11-01 16:10:05+00:00
# 2  rDxrpSqYHD8          @TS-rw4lk  2023-11-01 16:10:05+00:00
# 3  rDxrpSqYHD8           @ALONCAK  2023-11-01 16:10:06+00:00
# 4  rDxrpSqYHD8   @Rough_Estimates  2023-11-01 16:10:06+00:00
#
#                    updatedAt  likeCount  totalReplyCount  \
# 0  2023-11-01 16:10:43+00:00          4                4
# 1  2023-11-01 16:10:05+00:00          1                1
# 2  2023-11-01 16:10:05+00:00          0                0
# 3  2023-11-01 16:10:06+00:00          0                0
# 4  2023-11-01 16:10:06+00:00        135               14
#
#                                          textDisplay  \
# 0                      first now where is lei wulong
# 1  already seen it you are getting less views now...
# 2                                                wow
# 3                                          oww yeaah
# 4              i hope we get an angel version of jin
#
#        textStopWordsRemoved                  textTokenized  \
# 0                lei wulong                  [lei, wulong]
# 1  seen getting views bamco  [seen, getting, views, bamco]
# 2                       wow                          [wow]
# 3                 oww yeaah                   [oww, yeaah]
# 4    hope angel version jin    [hope, angel, version, jin]
#
#                 textLemmatized textTekkenCharactersRemoved  \
# 0                [lei, wulong]                          []
# 1      [see, get, view, bamco]     [see, get, view, bamco]
# 2                        [wow]                       [wow]
# 3                 [oww, yeaah]                [oww, yeaah]
# 4  [hope, angel, version, jin]             [hope, version]
#
#                             pos                posTag  \
# 0                 [PROPN, NOUN]             [NNP, NN]
# 1      [VERB, VERB, NOUN, NOUN]  [VBN, VBG, NNS, NNS]
# 2                        [INTJ]                  [UH]
# 3                [PROPN, PROPN]            [NNP, NNP]
# 4  [PROPN, PROPN, PROPN, PROPN]  [NNP, NNP, NNP, NNP]
#
#                           posDependency                  posShape  \
# 0                      [compound, ROOT]               [xxx, xxxx]
# 1             [ROOT, xcomp, dobj, dobj]  [xxxx, xxxx, xxxx, xxxx]
# 2                                [ROOT]                     [xxx]
# 3                      [compound, ROOT]               [xxx, xxxx]
# 4  [compound, compound, compound, ROOT]   [xxxx, xxxx, xxxx, xxx]
#
#                    posAlpha                   posStopWord
# 0              [True, True]                [False, False]
# 1  [True, True, True, True]  [False, False, False, False]
# 2                    [True]                       [False]
# 3              [True, True]                [False, False]
# 4  [True, True, True, True]  [False, False, False, False]

# %%
df.to_csv("data/processed/new_character_comments_processed_2.csv", index=False)

# %% [markdown]
# ## Check if any of the tokens are single or only two letter words

# %%
df_less_than = df.copy()

# %%
less_than_3 = []
for i, v in enumerate(df_less_than["textTekkenCharactersRemoved"]):
    for token in v:
        if len(token) <=2:
            less_than_3.append(token)
print(less_than_3)
# Out:
# ['yo', 'm', 'ps', 'st', 'go', 'vs', 'go', 'go', 'ok', 'go', 's', 'm', 'm', 'go', 'go', 'st', 'm', 's', 'dr', 'b', 'ak', 'm', 'd', 'os', 'tf', 'oh', 's', 'oh', 's', 's', 'd', 'd', 'go', 'fg', 'si', 'su', 'en', 'va', 'm', 'ii', 's', 'ps', 'b', 'f', 'xd', 'nt', 'dj', 'w', 's', 'oh', 's', 'ah', 'm', 'go', 's', 'iq', 'ak', 'br', 'm', 'nt', 's', 's', 'm', 'b', 'go', 'dr', 's', 'm', 'yo', 'sf', 'mk', 'ed', 's', 'l', 't', 'br', 'la', 'ii', 's', 's', 'va', 'go', 'm', 'ay', 'go', 'oh', 'go', 'go', 'mk', 's', '월에', '않네', 'm', 'go', 's', 've', 'fe', 'bb', 'yo', 'go', 'go', 's', 'tt', 'm', '_', 's', 'go', 'hi', '아', '뭐야', 'go', 'oh', 's', 'bb', 'ub', 's', 'm', 've', 's', 's', 't', 'ps', 'm', 't', 't', 's', 's', 'm', 'go', 'nt', 'm', 's', 't', 't', 'go', 'tl', 't', 'm', 'go', 'm', 'nt', 'nt', 'd', '와아', 'wu', 'm', 's', 'tf', 'из', 'p', 'go', 'qq', 'go', 'а', 'не', 'и', 'с', 'd', 'm', 'tt', 'go', 'go', 't', 'go', 'go', 'go', 'm', 's', 'sf', 'sc', 's', 'nt', 'sf', 's', 'm', 'ps', 'ps', 'og', 'oh', 'm', 'dj', 'm', 'go', 'be', 'ok', 've', 'mr', 've', 'm', 's', 'ai', 'el', 'ya', 'su', 'es', 'y', 'un', 'el', 'un', 'la', 'el', 's', 'm', 'm', 'go', 'dr', 'wa', 'm', 'y', 'en', 'el', 'go', 'p', 'o', 'o', 's', 'go', 'lo', 'en', 'go', 'aw', 'm', 's', 's', 'go', 't', 't', 't', 'nt', 't', 's', 'd', 'go', 'oc', 's', 's', '내놔', 'go', 'm', 'm', 't', 's', 'go', 'm', 'go', 'm', 'vs', 's', 'm', 'и', 'не', 'и', 'в', 'в', 'ob', 'es', 's', 'm', 'ah', 'gg', 'm', 'dr', 't', 'tf', 't', 'go', 'y', 's', 't', 'go', 'nt', '_', 's', 's', 'd', 'oh', 'af', '오예', '역시', '없지', 'ㅠㅠ', 'br', 'm', 'go', 'x', 'xd', 'wu', 'tf', 'ya', 'm', 'm', 'm', 't', 'm', 'ts', 'd', 'm', 'g', 'tf', '오우', 's', 'la', 'o', 's', 'y', 'sf', 'mk', 'bt', 'go', 't', 'm', 's', 'm', 'iz', 's', 'go', 'm', 'es', 'y', 'lo', 's', 'o', 'e', 'tf', 's', 's', 's', 'm', 's', 'nd', 'll', 'dx', 've', 'xd', 'm', 'w', 'dj', 'd', 't', 'n', 'vs', 's', 'nt', 'pc', 'm', 'nt', 've', 'd', 'd', 'oh', 'y', 's', 't', 'oh', 'l', 'ok', 'm', 'tf', 'go', 's', 'nd', 'yo', 'se', 'ce', 'nd', 'm', 'go', 's', 'go', 's', 'd', 'al', 'go', 's', 'go', 'il', 'ou', 'na', 'le', 'y', 'la', 'm', 'af', 'm', 'ok', 'os', 's', 'ok', 'oh', 'ie', 'oh', 'yo', 'y', 'es', 'и', 'm', 'dj', 'op', 'af', 'm', 'm', 'go', 's', 's', 's', 's', 'm', 's', 'd', 'ok', 'th', 'go', 'go', 'fk', 'go', 'ak', 'ak', 'dj', 'm', 'og', 't', 'tf', 's', 'm', 'ल', 'go', 'ok', 'y', 'yo', 'm', 'wu', 'go', 'li', '시발', '시발', 'ki', 'fr', 'ii', 'th', 'tf', 'd', 'm', 'tf', 'oh', 'y', 'o', 'go', 'nt', 'o', 'br', 'be', '태그', '부터', '너무', 's', 'go', 'dj', 's', 's', 'yo', 'th', 'dr', 'oh', 'll', 'go', 'tf', 'm', 's', 'm', 'vv', 'o', 'aí', 'dj', 'm', 'nt', 'm', 'm', 'go', 'go', 'el', 'lo', 's', 'go', 'm', 's', 'vs', 'd', 'up', 've', 't', 'm', 's', 'nt', 'nt', 's', 'oh', 'pc', 's', 'où', 'tf', 'th', 'xd', 'dr', 's', 'og', 'oh', 'p', 's', 'm', 't', 'e', 's', 's', 's', 's', 's', 'm', 'si', 'el', 'lo', 'va', 'd', 'ro', 'd', 's', 'y', 'pa', 'yo', 'ok', 'x', 'th', 'xd', 'm', 'go', 'go', 'ps', 'go', 'go', 'go', 'y', 'el', 'el', 'y', 'xd', 'l', 'tf', 'dr', 'd', 'br', 'nt', 's', 'gn', 'ok', 'e', 'o', 'é', 'go', 'c', 'og', 'm', 'go', 'm', 's', 'kj', 'kj', 'y', 'st', 'm', 'sf', 'o', 'nt', 'yt', 'tt', 's', 'tk', 'dr', 'b', 'da', 'm', 's', 'go', 'd', 's', 'go', 'm', 's', 'go', 'og', 'da', 'nt', 's', 'm', 'go']

# %% [markdown]
# There are loads of meaningless tokens that will clog up the model....remove them...

# %%
df_less_than["textTekkenCharactersRemoved"].iloc[5]
# Out:
# ['begin']

# %%
for i, v in enumerate(df_less_than["textTekkenCharactersRemoved"]):
    more_than_2 = [token for token in v if len(token) >2]
    df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# Out:
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# ...
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2
# /var/folders/lp/914jvm397pvf1h_lk1cb1gj80000gn/T/ipykernel_1655/3256966577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_than["textTekkenCharactersRemoved"].iloc[i] = more_than_2

# %%
less_than_3 = []
for i, v in enumerate(df_less_than["textTekkenCharactersRemoved"]):
    for token in v:
        if len(token) <=2:
            less_than_3.append(token)
print(less_than_3)
# Out:
# []

# %% [markdown]
# The above setting with copy warning should be eliminated when the code is functionalised and used with .apply()

# %%
def remove_tiny_tokens(tokens):
    """Removes tokens with less than 3 characters e.g., "fd", "a" etc.

    Parameters
    ----------
    tokens : list
        The list of tokens.

    Returns
    -------
    tokens : list
        The input list without tokens containing <=2 characters.
    
    """
    return [token for token in tokens if len(token) >2]

# %% [markdown]
# # Test function

# %%
df_test = df.copy()

# %%
less_than_3 = []
for i, v in enumerate(df_test["textTekkenCharactersRemoved"]):
    for token in v:
        if len(token) <=2:
            less_than_3.append(token)
print(less_than_3)
# Out:
# ['yo', 'm', 'ps', 'st', 'go', 'vs', 'go', 'go', 'ok', 'go', 's', 'm', 'm', 'go', 'go', 'st', 'm', 's', 'dr', 'b', 'ak', 'm', 'd', 'os', 'tf', 'oh', 's', 'oh', 's', 's', 'd', 'd', 'go', 'fg', 'si', 'su', 'en', 'va', 'm', 'ii', 's', 'ps', 'b', 'f', 'xd', 'nt', 'dj', 'w', 's', 'oh', 's', 'ah', 'm', 'go', 's', 'iq', 'ak', 'br', 'm', 'nt', 's', 's', 'm', 'b', 'go', 'dr', 's', 'm', 'yo', 'sf', 'mk', 'ed', 's', 'l', 't', 'br', 'la', 'ii', 's', 's', 'va', 'go', 'm', 'ay', 'go', 'oh', 'go', 'go', 'mk', 's', '월에', '않네', 'm', 'go', 's', 've', 'fe', 'bb', 'yo', 'go', 'go', 's', 'tt', 'm', '_', 's', 'go', 'hi', '아', '뭐야', 'go', 'oh', 's', 'bb', 'ub', 's', 'm', 've', 's', 's', 't', 'ps', 'm', 't', 't', 's', 's', 'm', 'go', 'nt', 'm', 's', 't', 't', 'go', 'tl', 't', 'm', 'go', 'm', 'nt', 'nt', 'd', '와아', 'wu', 'm', 's', 'tf', 'из', 'p', 'go', 'qq', 'go', 'а', 'не', 'и', 'с', 'd', 'm', 'tt', 'go', 'go', 't', 'go', 'go', 'go', 'm', 's', 'sf', 'sc', 's', 'nt', 'sf', 's', 'm', 'ps', 'ps', 'og', 'oh', 'm', 'dj', 'm', 'go', 'be', 'ok', 've', 'mr', 've', 'm', 's', 'ai', 'el', 'ya', 'su', 'es', 'y', 'un', 'el', 'un', 'la', 'el', 's', 'm', 'm', 'go', 'dr', 'wa', 'm', 'y', 'en', 'el', 'go', 'p', 'o', 'o', 's', 'go', 'lo', 'en', 'go', 'aw', 'm', 's', 's', 'go', 't', 't', 't', 'nt', 't', 's', 'd', 'go', 'oc', 's', 's', '내놔', 'go', 'm', 'm', 't', 's', 'go', 'm', 'go', 'm', 'vs', 's', 'm', 'и', 'не', 'и', 'в', 'в', 'ob', 'es', 's', 'm', 'ah', 'gg', 'm', 'dr', 't', 'tf', 't', 'go', 'y', 's', 't', 'go', 'nt', '_', 's', 's', 'd', 'oh', 'af', '오예', '역시', '없지', 'ㅠㅠ', 'br', 'm', 'go', 'x', 'xd', 'wu', 'tf', 'ya', 'm', 'm', 'm', 't', 'm', 'ts', 'd', 'm', 'g', 'tf', '오우', 's', 'la', 'o', 's', 'y', 'sf', 'mk', 'bt', 'go', 't', 'm', 's', 'm', 'iz', 's', 'go', 'm', 'es', 'y', 'lo', 's', 'o', 'e', 'tf', 's', 's', 's', 'm', 's', 'nd', 'll', 'dx', 've', 'xd', 'm', 'w', 'dj', 'd', 't', 'n', 'vs', 's', 'nt', 'pc', 'm', 'nt', 've', 'd', 'd', 'oh', 'y', 's', 't', 'oh', 'l', 'ok', 'm', 'tf', 'go', 's', 'nd', 'yo', 'se', 'ce', 'nd', 'm', 'go', 's', 'go', 's', 'd', 'al', 'go', 's', 'go', 'il', 'ou', 'na', 'le', 'y', 'la', 'm', 'af', 'm', 'ok', 'os', 's', 'ok', 'oh', 'ie', 'oh', 'yo', 'y', 'es', 'и', 'm', 'dj', 'op', 'af', 'm', 'm', 'go', 's', 's', 's', 's', 'm', 's', 'd', 'ok', 'th', 'go', 'go', 'fk', 'go', 'ak', 'ak', 'dj', 'm', 'og', 't', 'tf', 's', 'm', 'ल', 'go', 'ok', 'y', 'yo', 'm', 'wu', 'go', 'li', '시발', '시발', 'ki', 'fr', 'ii', 'th', 'tf', 'd', 'm', 'tf', 'oh', 'y', 'o', 'go', 'nt', 'o', 'br', 'be', '태그', '부터', '너무', 's', 'go', 'dj', 's', 's', 'yo', 'th', 'dr', 'oh', 'll', 'go', 'tf', 'm', 's', 'm', 'vv', 'o', 'aí', 'dj', 'm', 'nt', 'm', 'm', 'go', 'go', 'el', 'lo', 's', 'go', 'm', 's', 'vs', 'd', 'up', 've', 't', 'm', 's', 'nt', 'nt', 's', 'oh', 'pc', 's', 'où', 'tf', 'th', 'xd', 'dr', 's', 'og', 'oh', 'p', 's', 'm', 't', 'e', 's', 's', 's', 's', 's', 'm', 'si', 'el', 'lo', 'va', 'd', 'ro', 'd', 's', 'y', 'pa', 'yo', 'ok', 'x', 'th', 'xd', 'm', 'go', 'go', 'ps', 'go', 'go', 'go', 'y', 'el', 'el', 'y', 'xd', 'l', 'tf', 'dr', 'd', 'br', 'nt', 's', 'gn', 'ok', 'e', 'o', 'é', 'go', 'c', 'og', 'm', 'go', 'm', 's', 'kj', 'kj', 'y', 'st', 'm', 'sf', 'o', 'nt', 'yt', 'tt', 's', 'tk', 'dr', 'b', 'da', 'm', 's', 'go', 'd', 's', 'go', 'm', 's', 'go', 'og', 'da', 'nt', 's', 'm', 'go']

# %%
df_test["textTekkenCharactersRemoved"] = df_test["textTekkenCharactersRemoved"].apply(remove_tiny_tokens)

# %%
less_than_3 = []
for i, v in enumerate(df_test["textTekkenCharactersRemoved"]):
    for token in v:
        if len(token) <=2:
            less_than_3.append(token)
print(less_than_3)
# Out:
# []
